# %%
import pandas as pd
import datetime as dt
import pandas_datareader.data as web
from dash import Dash, html, dcc, callback, Output, Input
import plotly.express as px
import plotly.graph_objects as go
from dbclient import DatabaseClient
from financial_data import EurUsd_Daily
from datetime import datetime

# %%
aapl = web.DataReader('EUR/USD','stooq', start='1950-01-01', end='2025-01-01')

aapl = aapl.reset_index()


aapl
# Out:
# Empty DataFrame
# Columns: [No data]
# Index: []

# %%
fig = go.Figure(data=[go.Candlestick(x=aapl['Date'],
                open=aapl['Open'],
                high=aapl['High'],
                low=aapl['Low'],
                close=aapl['Close'])])

fig.show()

# %%
db_url = 'postgresql+psycopg2://postgres:postgres@localhost/financial_data'
dbclient = DatabaseClient(db_url)

data = dbclient.get_table_as_dataframe("eur_usd_daily")

data
# Out:
#                  open       high        low      close     volume
# date
# 2024-12-31  252.16300  253.00200  249.15600  250.14500   39524126
# 2024-12-30  251.95300  253.22200  250.47500  251.92300   35596636
# 2024-12-27  257.54700  258.41600  252.78200  255.30900   42401889
# 2024-12-26  257.90600  259.81400  257.34700  258.73600   27292958
# 2024-12-24  255.20900  257.92600  255.01000  257.91600   23260251
# ...               ...        ...        ...        ...        ...
# 1984-09-13    0.10323    0.10353    0.10323    0.10323  246058991
# 1984-09-12    0.10083    0.10142    0.09779    0.09779  157987052
# 1984-09-11    0.09991    0.10262    0.09991    0.10083  180849030
# 1984-09-10    0.09960    0.09991    0.09721    0.09901   76694011
# 1984-09-07    0.09960    0.10083    0.09840    0.09960   98811715
#
# [10160 rows x 5 columns]
